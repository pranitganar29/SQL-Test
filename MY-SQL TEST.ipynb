# %%
# Q.1    E-commerce Website Database:

# Scenario: You are tasked with designing the database for an e-commerce website. The system should handle product listings, 
#           customer accounts, orders, and inventory.
# Requirements:
# Store product information such as name, description, price, and quantity in stock.
# Allow customers to create accounts, log in, and maintain a shopping cart.
# Implement a secure order processing system that records order details (products, quantity, total cost).
# Track inventory levels and update them based on orders.
# Ensure data integrity and consistency in the database.

# %%
from IPython.display import Image

# Create Database :- 

# create database E_commerce_Website;

# %%
# Create table product information :-

# CREATE TABLE product_information( 
# product_id int not null PRIMARY KEY AUTO_INCREMENT, 
# name varchar(50), 
# description text, 
# price decimal, 
# quantity_in_stock int);

# Insert records in product information table :-

# INSERT INTO product_information
# (name, description, price, quantity_in_stock) 
# VALUES 
# ('Wireless Bluetooth Earbuds','Enjoy the freedom of movement with these high-quality wireless Bluetooth earbuds.',3000,5),
# (' Smart LED TV','Transform your living room into a home theater with our Smart LED TV. ',15000,7), 
# ('DSLR Camera',"Capture life's precious moments in stunning detail with our DSLR camera",25000,9), 
# ('Portable External Hard Drive','Safeguard your important files and take them with you wherever you go with our portable external hard drive.',5000,11);

# Show Table product information :-

# SELECT * FROM product_information;

product_information = 'D:\\pranit\\Ed-Byte\\Test\\product_information.jpg'

Image(filename = product_information )

# %%
# Create table customers information :-

# CREATE TABLE customers_information(
#     customers_id int not null PRIMARY KEY AUTO_INCREMENT,
#     full_name varchar(50),
#     address varchar(100),
#     email_id varchar(50),
#     user_name varchar(50),
#     user_password char(10));

# Insert records in customers information table :-

# INSERT INTO customers_information
# (full_name,address,email_id,user_name,user_password)
# VALUES
# ("John Doe", "123 Main Street, Cityville, USA", "john.doe@email.com", "johndoe123", "password123"),
# ("Alice Smith", "456 Oak Avenue, Townsville, USA", "alice.smith@email.com", "alicesmith456", "securepass"),
# ("Michael Johnson", "789 Elm Road, Villagetown, USA", "michael.johnson@email.com", "michaelj", "pass123word"),
# ("Emily Brown", "101 Pine Lane, Hamletown, USA", "emily.brown@email.com", "emilyb", "brownie123"),
# ("David Wilson", "222 Cedar Street, Suburbia, USA", "david.wilson@email.com", "davidw", "wilsonpass"),
# ("Sarah Lee", "333 Maple Drive, Countryside, USA", "sarah.lee@email.com", "sarahlee333", "password321"),
# ("James Taylor", "444 Birch Court, Hilltop, USA", "james.taylor@email.com", "jamest", "taylorpass"),
# ("Jennifer Martinez", "555 Walnut Avenue, Riverside, USA", "jennifer.martinez@email.com", "jenniferm", "martinez123");

# Show Table customers information :-

# SELECT * FROM customers_information;

customers_information = 'D:\\pranit\\Ed-Byte\\Test\\customers_information.jpg'

Image(filename = customers_information )

# %%
# Create table orders information :-

# CREATE TABLE orders_information(
#     order_id int not null PRIMARY KEY AUTO_INCREMENT,
#     customers_id int,
#     order_date datetime,
#     total_cost decimal,
#     order_status varchar(50),
#     FOREIGN KEY (customers_id) REFERENCES customers_information (customers_id);

# Insert records in orders information table :-

# INSERT INTO orders_information
# (customers_id,order_date,total_cost,order_status)
# VALUES
# (1,'2023-02-15',25000,'processing....'),
# (2,'2023-01-14',5000,'delivered'),
# (3,'2023-07-12',35000,'processing....'),
# (4,'2023-05-17',20000,'processing....'),
# (5,'2023-06-19',45000,'delivered'),
# (6,'2023-05-16',15000,'processing....'),
# (7,'2023-04-05',23000,'delivered.'),
# (4,'2023-04-18',30000,'delivered'),
# (6,'2023-03-12',28000,'processing....'),
# (8,'2023-11-25',42000,'delivered');

# Show Table orders information :-

# SELECT * FROM orders_information;

orders_information = 'D:\\pranit\\Ed-Byte\\Test\\orders_information.jpg'

Image(filename = orders_information )

# %%
# Create table orders details information :-

# CREATE TABLE orders_details(
#     orders_details_id int not null PRIMARY KEY AUTO_INCREMENT,
#     order_id int,
#     product_id int,
#     quantity int,
#     price decimal,
#     FOREIGN KEY (order_id) REFERENCES orders_information (order_id),
#     FOREIGN KEY (product_id) REFERENCES product_information (product_id));

# Insert records in orders details information table :-

# INSERT INTO orders_details
# (order_id,product_id,quantity,price)
# VALUES
# (1,2,2,30000),                # 1 :- 8
# (2,1,1,3000),                 # 2 :- 3
# (3,3,1,25000),                # 3 :- 3
# (4,4,2,10000),                # 4 :- 9
# (5,2,1,15000),
# (6,4,3,15000),
# (7,3,2,50000),
# (8,1,4,12000),
# (9,1,3,9000),
# (10,4,4,20000);

# Show Table orders details information :-

# SELECT * FROM orders_details;

orders_details_information = 'D:\\pranit\\Ed-Byte\\Test\\orders_details_information.jpg'

Image(filename = orders_details_information )

# %%
# Create table inventory details information :-

# CREATE TABLE inventory_details(
#     product_id int,
#     quantity int,
#     FOREIGN KEY (product_id) REFERENCES product_information (product_id));

# Insert records in inventory details information table :-

# insert into inventory_details
# VALUES
# (1,2),
# (2,7),
# (3,7),
# (4,1);

# Show Table inventory details information :-

# SELECT * FROM inventory_details;

inventory_details_information = 'D:\\pranit\\Ed-Byte\\Test\\inventory_details_information.jpg'

Image(filename = inventory_details_information )

# %%
# Q.2 
# Student Management System:

# Scenario: Design a database for a university's student management system. The system should handle student information, 
#           course registration, and grades.
# Requirements:
# Store student details including name, ID, contact information, and enrollment status.
# Manage course information, including course code, title, and instructor details.
# Allow students to register for courses and track their enrollment history.
# Record and calculate student grades for each registered course.
# Generate transcripts and reports for students.

# %%
# Create Database :- 

# create database university_student_management_system;

# %%
# Create table students information :-

# CREATE TABLE students_information(
#     student_id int not null primary key AUTO_INCREMENT,
#     student_name varchar(50),
#     last_name varchar(50),
#     email_id varchar(30),
#     enrollment_status varchar(30));

# Insert records in students information table :-

# INSERT into students_information
# (student_name,last_name,email_id,enrollment_status)
# VALUES
# ("John","Doe", "john.doe@email.com", "active"),
# ("Alice","Smith", "alice.smith@email.com", "active"),
# ("Michael","Johnson", "michael.johnson@email.com", "inactive"),
# ("Emily","Brown", "emily.brown@email.com", "active"),
# ("David","Wilson", "david.wilson@email.com", "active"),
# ("Sarah","Lee", "sarah.lee@email.com", "inactive"),
# ("James","Taylor", "james.taylor@email.com", "active");


# Show Table students information :-

# SELECT * FROM students_information;

students_information = 'D:\\pranit\\Ed-Byte\\Test\\students_information.jpg'

Image(filename = students_information )

# %%
# Create table course information :-

# CREATE TABLE course_information(
#     course_id int not null PRIMARY KEY AUTO_INCREMENT,
#     course_code varchar(10),
#     course_title varchar(30),
#     course_Instructor varchar(30));


# Insert records in course information table :-

# INSERT INTO course_information
# (course_code,course_title,course_Instructor)
# VALUES
# ('CSC101','Introduction to Computer Science','Dr. Amanda Johnson'),
# ('MAT201','Calculus I','Prof. Michael Smith'),
# ('ENG301','English Composition','Dr. Sarah Davis'),
# ('PSY401','Introduction to Psychology','Prof. Emily White');


# Show Table course information :-

# SELECT * FROM course_information;

course_information = 'D:\\pranit\\Ed-Byte\\Test\\course_information.jpg'

Image(filename = course_information )

# %%
# Create table registrations information :-

# CREATE TABLE registrations_information(
#     registrations_id int not null PRIMARY KEY AUTO_INCREMENT,
#     student_id int,
#     course_id int,
#     registrations_date datetime,
#     FOREIGN KEY (student_id) REFERENCES students_information (student_id),
#     FOREIGN KEY (course_id) REFERENCES course_information (course_id));

# Insert records in registrations information table :-

# INSERT INTO registrations_information
# (student_id,course_id,registrations_date)
# VALUES
# (1,2,'2024-01-15'),
# (2,1,'2024-01-15'),
# (3,1,'2024-01-15'),
# (4,4,'2024-01-15'),
# (5,4,'2024-01-15'),
# (6,3,'2024-01-15'),
# (7,1,'2024-01-15'),
# (5,2,'2024-01-15'),
# (2,1,'2024-01-15'),
# (1,3,'2024-01-15');

# Show Table registrations information :-

# SELECT * FROM registrations_information;

registrations_information = 'D:\\pranit\\Ed-Byte\\Test\\registrations_information.jpg'

Image(filename = registrations_information )

# %%
# Create table grade information :-

# CREATE TABLE grade_information(
#     grade_id int not null PRIMARY KEY AUTO_INCREMENT,
#     registrations_id int,
#     grade char(2));

# Insert records in grade information table :-

# INSERT INTO grade_information
# (registrations_id,grade)
# VALUES
# (1,'A'),
# (2,'B'),
# (3,'B+'),
# (4,'A+'),
# (5,'C'),
# (6,'A'),
# (7,'C'),
# (8,'B'),
# (9,'C+'),
# (10,'A+');

# Show Table grade information :-

# SELECT * FROM grade_information;

grade_information = 'D:\\pranit\\Ed-Byte\\Test\\grade_information.jpg'

Image(filename = grade_information )

# %%
# Create table transcripts information :-

# CREATE TABLE transcripts_information(
#     transcripts_id int not null PRIMARY KEY AUTO_INCREMENT,
#     student_id int,
#     course_id int,
#     grade char(2),
#     FOREIGN KEY (student_id) REFERENCES students_information (student_id),
#     FOREIGN KEY (course_id) REFERENCES course_information (course_id));

# Insert records in transcripts information table :-

# INSERT INTO transcripts_information
# (student_id,course_id,grade)
# VALUES
# (1,2,'A'),
# (2,4,'C'),
# (3,3,'A+'),
# (4,1,'B+'),
# (5,3,'B'),
# (6,2,'A'),
# (7,4,'B+'),
# (2,1,'A+'),
# (4,4,'C'),
# (6,3,'B'),
# (3,2,'C'),
# (5,1,'A+');

# Show Table transcripts information :-

# SELECT * FROM transcripts_information;

transcripts_information = 'D:\\pranit\\Ed-Byte\\Test\\transcripts_information.jpg'

Image(filename = transcripts_information )

# %%
# Q.3 
# Blog Platform Database:

# Scenario: You are developing a blog platform where users can create accounts, write posts, and interact with each other 
#           through comments.
# Requirements:
# Store user information including username, email, and password securely.
# Enable users to create, edit, and delete their blog posts.
# Implement a commenting system, linking comments to specific posts.
# Provide a notification system for users to receive updates on new comments or posts.
# Optimize the database for efficient retrieval of blog posts and comments.

# %%
# Create Database :- 

# CREATE DATABASE Blog_Platform;

# %%
# Create table user information :-

# CREATE TABLE user_infirmation(
#     user_id int not null PRIMARY KEY AUTO_INCREMENT,
#     full_name varchar(50),
#     user_name varchar(50),
#     user_password varchar(20));

# Insert records in user information table :-

# INSERT INTO user_infirmation
# (full_name,email_id,user_name,user_password)
# VALUES
# ('John Doe','john.doe@email.com',"johndoe123", "password123"),
# ('Alice Smith','alice.smith@email.com',"alicesmith456", "securepass"),
# ('Michael Johnson','michael.johnson@email.com',"michaelj", "pass123word"),
# ('Emily Brown','emily.brown@email.com',"emilyb", "brownie123"),
# ('David Wilson','david.wilson@email.com',"davidw", "wilsonpass"),
# ('Sarah Lee','sarah.lee@email.com',"sarahlee333", "password321");


# Show Table user information :-

# SELECT * FROM user_infirmation;


user_infirmation = 'D:\\pranit\\Ed-Byte\\Test\\user_infirmation.jpg'

Image(filename = user_infirmation )

# %%
# Create table post information :-

# CREATE TABLE post_information(
#     post_id int not null PRIMARY KEY AUTO_INCREMENT,
#     user_id int,
#     post_title varchar(50),
#     content varchar(200),
#     post_date date,
#     FOREIGN KEY (user_id) REFERENCES user_infirmation (user_id));

# Insert records in post information table :-

# INSERT INTO post_information
# (user_id,post_title,content,post_date)
# VALUES
# (1,"Exploring the Beauty of Nature","Nature has always been a source of wonder and inspiration for me","2024-01-15"),
# (2,"The Art of Mindfulness","Mindfulness is a practice that has transformed my life in countless ways.","2024-02-25"),
# (3,"A Journey Through History","History has always fascinated me, from ancient civilizations to modern-day events.","2024-01-12"),
# (4,"The Power of Gratitude","Gratitude is a powerful force that can transform our lives and relationships.","2024-01-05"),
# (5,"The Magic of Music","Music has the remarkable ability to evoke emotions, transport us to different worlds, and unite people across cultures and languages","2024-02-09"),
# (6,"The Joy of Travel","Traveling opens our eyes to new cultures, landscapes, and experiences, enriching our lives in ways we never imagined.","2024-01-19");


# Show Table post information :-

# SELECT * FROM post_information;


post_information = 'D:\\pranit\\Ed-Byte\\Test\\post_information.jpg'

Image(filename = post_information )

# %%
# Create table comment information :-

# CREATE TABLE comment_information(
#     comment_id int not null PRIMARY KEY AUTO_INCREMENT,
#     user_id int,
#     post_id int,
#     comment_content varchar(200),
#     comment_date date,
#     FOREIGN KEY (user_id) REFERENCES user_infirmation (user_id),
#     FOREIGN KEY (post_id) REFERENCES post_information (post_id));

# Insert records in comment information table :-

# INSERT INTO comment_information
# (user_id,post_id,comment_content,comment_date)
# VALUES
# (1,2,'Good content','2024-02-26'),
# (2,3,'Nice content','2024-01-14'),
# (3,4,'Good content','2024-01-07'),
# (4,5,'Nice content','2024-02-11'),
# (5,6,'Good content','2024-01-20'),
# (6,1,'Nice content','2024-01-18');

# Show Table comment information :-

# SELECT * FROM comment_information;


comment_information = 'D:\\pranit\\Ed-Byte\\Test\\comment_information.jpg'

Image(filename = comment_information )

# %%
# Create table notification information :-

# CREATE TABLE notification_information(
#     notification_id int not null PRIMARY KEY AUTO_INCREMENT,
#     user_id int,
#     notification_type varchar(50),
#     notification_date date,
#     FOREIGN KEY (user_id) REFERENCES user_infirmation (user_id));


# Insert records in notification information table :-

# INSERT INTO notification_information
# (user_id,notification_type,notification_date)
# VALUES
# (1,'New Post','2024-01-15'),
# (2,'New Comment','2024-01-14'),
# (3,'New Post','2024-01-12'),
# (4,'New Comment','2024-02-11'),
# (5,'New Post','2024-02-09'),
# (6,'New Comment','2024-01-18');

# Show Table notification information :-

# SELECT * FROM notification_information;


notification_information = 'D:\\pranit\\Ed-Byte\\Test\\notification_information.jpg'

Image(filename = notification_information )
